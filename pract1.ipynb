# %% [markdown]
# <a href="https://colab.research.google.com/github/SofiaNikolaeva-adey-201/OPDA-practiki/blob/19.02.2021/pract1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Построение кривых с помощью команды plot

# %% [markdown]
# ПРИМЕР 1

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.arange(0, np.pi*2, 0.05)
y = np.sin(x)
plt.plot(x, y)
plt.xlabel('Угол')
plt.ylabel('sin()')
plt.title('Тригонометрич ф-ция')
# Out:
# Text(0.5, 1.0, 'Тригонометрич ф-ция')

# %% [markdown]
# ПРИМЕР 2

# %%
from numpy import *
from pylab import *
x = linspace(-3, 3, 30)
y = x ** 2
plot(x, y)
show()

# %% [markdown]
# ПРИМЕР 3

# %% [markdown]
# пример с помощью объектов

# %%
from matplotlib import pyplot as plt
import numpy as np
import math
x = np.arange(0, np.pi*2, 0.05)
y = np.sin(x)
fig = plt.figure()
ax = fig.add_axes([0, 0, 1, 1])
ax.plot(x, y)
ax.set_title("Тригон ф-ция")
ax.set_xlabel('угол')
ax.set_ylabel('sin()')
plt.show()

# %% [markdown]
# ПРИМЕР 4

# %%
import matplotlib.pyplot as plt
y = [1, 4, 9, 16, 25, 36, 49, 64]
x1 = [1, 16, 30, 42, 55, 68, 77, 88]
x2 = [1, 6, 12, 18, 28, 40, 52, 65]
fig = plt.figure()
ax = fig.add_axes([0, 0, 1, 1])
l1 = ax.plot(x1,y, 'ys-')
l2 = ax.plot(x2,y, 'go--')
ax.legend(labels = ('tv', 'smartfone'), loc = 'lower right')
ax.set_title('advert')
ax.set_xlabel('medium')
ax.set_ylabel('sales')
plt.show()

# %% [markdown]
# ПРИМЕР 5

# %%
import matplotlib.pyplot as plt
a1 = plt.subplot2grid((3,3),(0,0),colspan = 2)
a2 = plt.subplot2grid((3,3),(0,2),rowspan = 3)
a3 = plt.subplot2grid((3,3),(1,0),rowspan = 2, colspan = 2)
import numpy as np
x = np.arange(1,10)
a2.plot(x,x*x, '--bo')
a2.set_title('square')
a1.plot(x, np.exp(x), 'ys-')
a1.set_title('exp')
a3.plot(x,np.log(x), 'ys-')
a3.set_title('log')
plt.tight_layout()
plt.show()

# %% [markdown]
# ПРИМЕР 6

# %%
import matplotlib.pyplot as plt
fig,a = plt.subplots(2,2)
import numpy as np
x = np.arange(1,5)
a[0][0].plot(x, x*x)
a[0][0].set_title('square')
a[0][1].plot(x,np.sqrt(x))
a[0][1].set_title('square root')
a[1][0].plot(x,np.exp(x))
a[1][0].set_title('exp')
a[1][1].plot(x,np.log10(x))
a[1][1].set_title('log')
plt.show()

# %% [markdown]
# ПРИМЕР 7

# %%
import matplotlib.pyplot as plt
plt.plot([1,2,3])
plt.subplot(211)
plt.plot(range(12))
plt.subplot(212, facecolor = 'y')
plt.plot(range(12))

# %% [markdown]
# ПРИМЕР 8

# %%
import matplotlib.pyplot as plt
import numpy as np
import math
x = np.arange(0, np.pi*2, 0.05)
fig = plt.figure()
axes1 = fig.add_axes([0.1, 0.1, 0.8, 0.8])
axes2 = fig.add_axes([0.55, 0.55, 0.3, 0.3])
y = np.sin(x)
axes1.plot(x, y, 'b')
axes2.plot(x, np.cos(x), 'r')
axes1.set_title('sin')
axes2.set_title('cosin')
plt.show()

# %% [markdown]
# ПРИМЕР 9

# %%
import matplotlib.pyplot as plt
ax1 = fig.add_subplot(111)
fig = plt.figure()
ax1.plot([1,2,3])
ax2 = fig.add_subplot(221, facecolor = 'y')
ax2.plot([1,2,3])

# %% [markdown]
# ГИСТОГРАММЫ

# %% [markdown]
# ПРИМЕР 10

# %%
import matplotlib.pyplot as plt
fig = plt.figure()
ax = fig.add_axes([0, 0, 1, 1])
langs = ['C', 'C++', 'Java', 'Python', 'PHP']
students = [23, 17, 35, 29, 12]
ax.bar(langs, students)
plt.show()

# %% [markdown]
# ПРИМЕР 11

# %%
import numpy as np
import matplotlib.pyplot as plt
data = [[30, 25, 50, 20], [40, 23, 51, 17], [35, 22, 45, 19]]
X = np.arange(4)
fig = plt.figure()
ax = fig.add_axes([0, 0, 1, 1])
ax.bar(X + 0.00, data[0], color = 'b', width = 0.25)
ax.bar(X + 0.25, data[1], color = 'g', width = 0.25)
ax.bar(X + 0.50, data[2], color = 'r', width = 0.25)
# Out:
# <BarContainer object of 4 artists>

# %% [markdown]
# КРУГОВАЯ ДИАГРАМММА

# %% [markdown]
# ПРИМЕР 12

# %%
import numpy as np
import matplotlib.pyplot as plt
fig = plt.figure()
ax = fig.add_axes([0, 0, 1, 1])
ax.axis('equal')
langs = ['C', 'C++', 'Java', 'Python', 'PHP']
students = [23, 17, 35, 29, 12]
ax.pie(students, labels = langs, autopct = '%1.2f%%')
plt.show()

# %% [markdown]
# ИЗ ЛАБЫ

# %% [markdown]
# ПРИМЕР 13

# %%
from google.colab import files
uploaded = files.upload()
for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(name = fn, length = len(uploaded[fn])))
# Out:
#      <input type="file" id="files-74084851-a02c-40cf-a228-24f3dba27d1d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-74084851-a02c-40cf-a228-24f3dba27d1d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving test.txt to test.txt
# User uploaded file "test.txt" with length 13 bytes

# %%
import matplotlib.pyplot as plt
with open('test.txt') as f:
  data = f.read()
data = data.split('\n')
x = [row.split(' ')[0] for row in data]
y = [row.split(' ')[1] for row in data]
plt.plot(x, y)
plt.xlabel('ось х')
plt.xlabel('ось у')
plt.title('данные из файла')
plt.show()

# %% [markdown]
# ПРИМЕР 14

# %%
from google.colab import files
uploaded = files.upload()
for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(name = fn, length = len(uploaded[fn])))
# Out:
#      <input type="file" id="files-5941277d-bdca-403e-a9ed-cc0b28806165" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-5941277d-bdca-403e-a9ed-cc0b28806165">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving fdata.csv to fdata.csv
# User uploaded file "fdata.csv" with length 273 bytes

# %%
import matplotlib.pyplot as plt
import pandas as pd
df = pd.read_csv('fdata.csv', sep = ',', parse_dates=True, index_col = 0)
df.plot()
plt.show()
